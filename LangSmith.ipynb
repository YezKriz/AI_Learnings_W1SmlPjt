# %%
# LANGSMITH is a web-based platform that records and shows everything what your app does.

# the questions that came in,
# the prompts sent to the model, models replay, howmany tocakens were used, how long it took to get the response,
# This recording is called tracing. It helps you see debug, and improve your app.

# LangSmith is like a CCTV camera for your AI app, 
# Using LangSmith you can see what your app is doing, and how it is doing it. You can see the prompts sent to the model,
# the responses received, and how long it took to get those responses.
# This information can help you debug your app, improve its performance, and make it more efficient.    
# YOU CAN PLAY BACK THE TRACE AND SEE WHAT HAPPENED IN YOUR APP, AND HOW IT HAPPENED.
